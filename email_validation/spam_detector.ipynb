# %%
# %pip install numpy pandas scikit-learn

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report

df = pd.read_csv("datasets/spam.csv", encoding="latin-1")
print(df.head())

# Data Cleaning and preprocessing
df = df[["v1", "v2"]]
df.columns = ["label","text"]

df.dropna(inplace = True)
df.drop_duplicates(inplace = True)

print(f"The length of the dataset is: {len(df)}")

df['label'] = df["label"].lower().strip()
df["label"] = df
df["label"] = df['label'].map({
   "ham": 1,
   "spam" : 0 
})
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\dubai laptop bazar\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
# The length of the dataset is: 5572
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
